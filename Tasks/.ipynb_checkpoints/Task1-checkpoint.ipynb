# %% [markdown]
# # Задание №1
# ## Выполнил студент группы БВТ2005 Макбари Даниш Александрович

# %% [markdown]
# ### Оглавление
# 1. [Задание 1](#Задание-№1)
# 2. [Задание 2](#Задание-№2)
# 3. [Задание 3](#Задание-№3)
# 4. [Вывод](#Вывод)

# %% [markdown]
# ### Задание №1
# Массив A состоит из целых положительных чисел длин отрезков. Составьте из трех отрезков такой треугольник, чтобы его периметр был максимально возможным. Если невозможно составить треугольник с положительной площадью функция возвращает 0.

# %%
import random

def check_sides(a, b, c, p):
    if (a >= b + c or b >= a + c or c >= a + b or p > a + b + c):
        return False
    return True

def triangle(A):
    A.sort(reverse = True)
    sides = []
    maxp = 0
    for i in range(2, len(A)):
        if check_sides(A[i - 2], A[i - 1], A[i], maxp):
            maxp = A[i - 2] + A[i - 1] + A[i]
            sides = [A[i - 2], A[i - 1], A[i]]
    if maxp == 0:
        return maxp
    return sides

A = []
for i in range(10):
    A.append(random.randint(1, 10))
print(A)
print(triangle(A))
# Out:
# [5, 10, 10, 5, 5, 5, 2, 2, 9, 7]
# [10, 10, 9]

# %% [markdown]
# ### Задание №2
# Дан массив неотрицательных целых чисел nums. Расположите их в таком порядке, чтобы вместе они образовали максимально возможное число. Замечание: Результат может быть очень большим числом, поэтому представьте его как string, а не integer.

# %%
import random

def big_number(nums):
    for i in range(len(nums)):
        nums[i] = str(nums[i])
    nums.sort(reverse = True)
    retnum = ""
    for i in range(len(nums)):
        retnum += nums[i]
    return retnum

nums = []
for i in range(15):
    nums.append(random.randint(0, 1000))

print(nums)
print(big_number(nums))
# Out:
# [800, 218, 2, 702, 300, 849, 522, 810, 532, 896, 10, 73, 566, 857, 461]
# 89685784981080073702566532522461300218210

# %% [markdown]
# ### Задание №3
# Дана матрица mat размером m * n, значения целочисленные. Напишите функцию, сортирующую каждую диагональ матрицы по возрастанию и возвращающую получившуюся матрицу.

# %% [markdown]
# ### Вывод
